# %%
import pandas as pd
from sklearn.metrics.pairwise.cosine_similarity

# %%
matrix = pd.read_csv('../DSI---Capstone-Project/matrix.csv')

# %%
matrix
# Out:
#                                                     user_000001  user_000002  \
# !!!: All My Heroes Are Weirdos                              0.0          0.0
# !!!: Bend Over Beethoven                                    0.0          0.0
# !!!: Dear Can                                               0.0          0.0
# !!!: Heart Of Hearts                                        0.0          0.0
# !!!: Must Be The Moon                                       0.0          0.0
# !!!: Myth Takes                                             0.0          0.0
# !!!: Pardon My Freedom                                      0.0          0.0
# !!!: Sweet Life                                             0.0          0.0
# !!!: Yadnus                                                 0.0          0.0
# !Cube: Back To Basics                                       0.0          0.0
# "Weird Al" Yankovic: Polkarama!                             0.0          0.0
# ...

# %%
find each users average play count (ignoring 0)
subtract this from each non 0 play count
computer cosine of centered ratings vectors
